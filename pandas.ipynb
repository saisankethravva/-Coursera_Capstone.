# %%
import os
import pandas
df1=pandas.read_json("supermarkets (1).json")
print(df1)
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df1
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df1.loc[5,"Country"]
# Out:
# 'USA'

# %%
df1
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df1.loc[4,"City":"Name"]
# Out:
# City         San Francisco
# Country                USA
# Employees               12
# ID                       5
# Name               Sanchez
# Name: 4, dtype: object

# %%
df1.iloc[1:3,1]
# Out:
# 1    San Francisco
# 2    San Francisco
# Name: City, dtype: object

# %%
df1
# Out:
#             Address           City Country  Employees         Name  \
# ID
# 1      3666 21st St  San Francisco     USA          8      Madeira
# 2    735 Dolores St  San Francisco     USA         15  Bready Shop
# 3       332 Hill St  San Francisco     USA         25  Super River
# 4      3995 23rd St  San Francisco     USA         10   Ben's Shop
# 5   1056 Sanchez St  San Francisco     USA         12      Sanchez
# 6   551 Alvarado St  San Francisco     USA         20   Richvalley
#
#                State
# ID
# 1           CA 94114
# 2           CA 94119
# 3   California 94114
# 4           CA 94114
# 5         California
# 6           CA 94114

# %% [markdown]
# # df1["vechile"]=df1["volvo,"benzz","audi","jauger","bolt","bugati"]

# %%
df1["City"]=["volvo","benz","audi","jqasd","bugati","landrover"]
df1
# Out:
#            Address       City Country  Employees  ID         Name  \
# 0     3666 21st St      volvo     USA          8   1      Madeira
# 1   735 Dolores St       benz     USA         15   2  Bready Shop
# 2      332 Hill St       audi     USA         25   3  Super River
# 3     3995 23rd St      jqasd     USA         10   4   Ben's Shop
# 4  1056 Sanchez St     bugati     USA         12   5      Sanchez
# 5  551 Alvarado St  landrover     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
df3
# Out:
# ID                    1               2                 3             4  \
# Address    3666 21st St  735 Dolores St       332 Hill St  3995 23rd St
# City              volvo            benz              audi         jqasd
# Country             USA             USA               USA           USA
# Employees             8              15                25            10
# Name            Madeira     Bready Shop       Super River    Ben's Shop
# State          CA 94114        CA 94119  California 94114      CA 94114
# vechile           volvo            benz              audi         jqasd
#
# ID                       5                6
# Address    1056 Sanchez St  551 Alvarado St
# City                bugati        landrover
# Country                USA              USA
# Employees               12               20
# Name               Sanchez       Richvalley
# State           California         CA 94114
# vechile             bugati        landrover

# %% [markdown]
# # df1_t=df1.T
# df_t

# %%
df3=df1.T
df3["studies"]=["M.COM","B.COM","B.TECH","P.HD","MBBS","m.tech","no study"]
df3
# Out:
#                       0               1                 2             3  \
# Address    3666 21st St  735 Dolores St       332 Hill St  3995 23rd St
# City              volvo            benz              audi         jqasd
# Country             USA             USA               USA           USA
# Employees             8              15                25            10
# ID                    1               2                 3             4
# Name            Madeira     Bready Shop       Super River    Ben's Shop
# State          CA 94114        CA 94119  California 94114      CA 94114
#
#                          4                5   studies
# Address    1056 Sanchez St  551 Alvarado St     M.COM
# City                bugati        landrover     B.COM
# Country                USA              USA    B.TECH
# Employees               12               20      P.HD
# ID                       5                6      MBBS
# Name               Sanchez       Richvalley    m.tech
# ...

# %%
dk=pandas.read_csv("supermarkets.csv")
dk
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
from geopy import ArcGIS
x=ArcGIS()
a=x.geocode("mattawada,warangal,india")
print(a)
print(a.latitude)
a.longitude

# %%
dk
# Out:
#    ID          Address           City             State Country         Name  \
# 0   1     3666 21st St  San Francisco          CA 94114     USA      Madeira
# 1   2   735 Dolores St  San Francisco          CA 94119     USA  Bready Shop
# 2   3      332 Hill St  San Francisco  California 94114     USA  Super River
# 3   4     3995 23rd St  San Francisco          CA 94114     USA   Ben's Shop
# 4   5  1056 Sanchez St  San Francisco        California     USA      Sanchez
# 5   6  551 Alvarado St  San Francisco          CA 94114     USA   Richvalley
#
#    Employees
# 0          8
# 1         15
# 2         25
# 3         10
# 4         12
# 5         20

# %%
dk["Address"]=dk["Address"]+","+dk["City"]+","+dk["State"]+","+dk["Country"]
dk["Location"]=dk["Address"].apply(x.geocode)
dk["Latitude"]=dk["Location"].apply(lambda x:x.latitude)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# C:\ProgramData\Anaconda3\lib\site-packages\geopy\geocoders\base.py in _call_geocoder(self, url, timeout, raw, requester, deserializer, **kwargs)
#     343         try:
# --> 344             page = requester(req, timeout=timeout, **kwargs)
#     345         except Exception as error:
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in open(self, fullurl, data, timeout)
#     525
# --> 526         response = self._open(req, data)
#     527
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in _open(self, req, data)
#     543         result = self._call_chain(self.handle_open, protocol, protocol +
# --> 544                                   '_open', req)
#     545         if result:
#
# C:\ProgramData\Anaconda3\lib\urllib\request.py in _call_chain(self, chain, kind, meth_name, *args)
# ...

# %%
dk
